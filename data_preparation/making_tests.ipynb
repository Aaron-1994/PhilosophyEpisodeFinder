# %%
import torch
import time
import os
import langchain
from langchain.chat_models import ChatOpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from loguru import logger
from dotenv import load_dotenv
from math import ceil
load_dotenv()
num_question_to_make_per_hundred = 10

# %%
chat = ChatOpenAI(model_name='gpt-3.5-turbo-16k')

import pandas as pd
res = []
columns = ["EPI_NUM", "EpiName", "Podcast", "Person", "Abstract"]
df = pd.DataFrame(columns=columns)
df.set_index("EPI_NUM", drop=True, append=False, inplace=False, verify_integrity=False)
print(df)

pd.__version__


def pipeline_cleanup(doc):
    root_prompt = f"""I want you to clean up the following text downloaded from a webpage. 
    Our goal is to keep the actual article without changing the content. 
    1. remove social media, privacy stuff from the end of the document.
    3. Only return the cleaned up article, and nothing else. """ 
    
    
    prompt1 = f"""
    -----------article-----------------  
    {doc}
    """
    
    messages = [
        SystemMessage(content=root_prompt),
        HumanMessage(content=prompt1)
    ]
    
    cleaned_text = chat(messages).content
    return cleaned_text

def pipeline_write_questions(doc):
    root_prompt = f"""Write two questions based on the given document. 
    
    [Q1]. Write a ONE PART question about someone's work discussed in the document - The question should not need any context to be understandable. 
    [Q2]. Write a ONE PART question about an abstract subject discussed in the document. - - The question should not need any context to be understandable. 
    
    
    Questions have to make sense without any context.
    Questions should have only on part.
    
    Avoid the following:
        Questions do not point to the article. 
        The words "article" and its synonyms.
        The words "author" and its synonyms.
        The words "author" and its synonyms.


    GOOD EXAMPLES:
        1. What was Immanuel Kant's preoccupation regarding working out things about the world without experience?
        2. What did Peter Singer argue in his book "The Life You Can Save"?
    
    
    BAD EXAMPLES:
        1. Who is being interviewed in this episode of Philosophy Bites? (requires context)
        2. Have I killed the man intentionally? (requires context)
        3. What is the main theme or concept discussed in the article? (requires context)
        4. Can you explain what metaphysics is and how it can be characterized? (Two parts)
        5. What are green virtues and why should we be concerned with them? (Two parts)
    
    do not output anything but the questions listed in the above order.
    """ 
    
    
    prompt1 = f"""
    -----------article-----------------  
    {doc}
    """
    
    
    messages = [
        SystemMessage(content=root_prompt),
        HumanMessage(content=prompt1)
    ]
    
    ai_questions = chat(messages).content
    return ai_questions


def parse_ai_questions(ai_questions, doc_idx, podcast_title, episode_title):
    qs = ai_questions.split('\n')
    question_dict = {"EPI_NUM": doc_idx ,"EpiName": episode_title, "Podcast":podcast_title}

    question_type = {
                "Q1":"Person",
                "Q2":"Abstract",
                }

    for q in qs:
        q_code = q[1:3]
        if q_code in question_type:
            q_type = question_type[q_code]
            question_dict[q_type] = q[5:]
    
    logger.info(f"{doc_idx}, {question_dict}")
    return question_dict
# Out:
# Empty DataFrame
# Columns: [EPI_NUM, EpiName, Podcast, Person, Abstract]
# Index: []

# %%
import time
# from engine.constants import Podcast
from datetime import date
from math import ceil
# cleaning data for Philosophize This
base_url = ".\..\data\philosophize_this\episode_transcripts" 
transcripts_path = base_url

res = []
cleaned_docs = {}

transcripts = os.listdir(transcripts_path)

pz_episode_count = len(transcripts)


num_questions_to_make = num_question_to_make_per_hundred * ceil(pz_episode_count / 100) * 2
print(num_questions_to_make)
# Out:
# 40

# %%
pz_episode_indices = torch.randint(1, pz_episode_count, (num_questions_to_make + 5, )).unique()


pz_episode_indices = sorted(pz_episode_indices.tolist())
pz_episode_indices = [10, 12, 15, 16, 19, 27, 31, 32, 41, 47, 48, 58, 61, 63, 64, 73, 75, 76, 86, 88, 90, 92, 93, 100, 103, 104, 106, 108, 114, 115, 120, 121, 123, 127, 128, 129, 131, 132, 142, 145, 152, 160, 169, 170, 173, 176]
print(pz_episode_indices)
print(len(pz_episode_indices))
# Out:
# [10, 12, 15, 16, 19, 27, 31, 32, 41, 47, 48, 58, 61, 63, 64, 73, 75, 76, 86, 88, 90, 92, 93, 100, 103, 104, 106, 108, 114, 115, 120, 121, 123, 127, 128, 129, 131, 132, 142, 145, 152, 160, 169, 170, 173, 176]
# 46

# %%
import os

processed_url = ".\\..\\data\\philosophize_this\\transcripts_processed" 


for doc_idx in pz_episode_indices:
    doc_path = f"{base_url}\{str(doc_idx).rjust(3, '0')}.txt"
    cleaned_doc_path = r"{processed_url}\\{doc_idx}.txt".format(processed_url=processed_url, doc_idx=doc_idx)
    if not os.path.isfile(cleaned_doc_path):
        print(f"Cleaning for {doc_idx}")
        # open the raw doc
        doc = open(doc_path, 'r', encoding="utf8").read()
        logger.info(f"loading {doc_idx} done, cleaning")
        # clean up the doc
        cleaned_doc = pipeline_cleanup(doc)
        cleaned_docs[doc_idx] = cleaned_doc
        time.sleep(2)
        # save the doc in cleaned documents
        f = open(f"{doc_idx}.txt", 'a+')
        f.write(cleaned_doc)
        f.close()
    else: # open the doc
        print(f"Loading doc {doc_idx} from cache")
        cleaned_doc_file = open(cleaned_doc_path, 'r')
        cleaned_docs[doc_idx] = cleaned_doc_file.read()
    
    

# question creation pipeline 
        


transcripts = os.listdir(transcripts_path)




# podcast_title = Podcast.PHILOSOPHIZE_THIS
podcast_title = "Philosophize This"
# Out:
# Loading doc 10 from cache
# Loading doc 12 from cache
# Loading doc 15 from cache
# Loading doc 16 from cache
# Loading doc 19 from cache
# Loading doc 27 from cache
# Loading doc 31 from cache
# Loading doc 32 from cache
# Loading doc 41 from cache
# Loading doc 47 from cache
# Loading doc 48 from cache
# Loading doc 58 from cache
# Loading doc 61 from cache
# Loading doc 63 from cache
# Loading doc 64 from cache
# Loading doc 73 from cache
# Loading doc 75 from cache
# Loading doc 76 from cache
# Loading doc 86 from cache
# Loading doc 88 from cache
# Loading doc 90 from cache
# Loading doc 92 from cache
# Loading doc 93 from cache
# Loading doc 100 from cache
# Loading doc 103 from cache
# Loading doc 104 from cache
# Loading doc 106 from cache
# Loading doc 108 from cache
# Loading doc 114 from cache
# Loading doc 115 from cache
# Loading doc 120 from cache
# Loading doc 121 from cache
# Loading doc 123 from cache
# Loading doc 127 from cache
# Loading doc 128 from cache
# Loading doc 129 from cache
# Loading doc 131 from cache
# Loading doc 132 from cache
# Loading doc 142 from cache
# Loading doc 145 from cache
# Loading doc 152 from cache
# Loading doc 160 from cache
# Loading doc 169 from cache
# Loading doc 170 from cache
# Loading doc 173 from cache
# Loading doc 176 from cache

# %%
# question creation pipeline


today = date.today()
for doc_idx in pz_episode_indices:
    doc = cleaned_docs[doc_idx]
    ai_questions = pipeline_write_questions(doc)
    logger.info(ai_questions)
    res.append((doc_idx, ai_questions))
    questions = parse_ai_questions(ai_questions, doc_idx, podcast_title=podcast_title, episode_title=doc_idx) # episode title is not passed correctly
    for key, val in questions.items():
        logger.info(f"{key}: {val}")
    df.loc[len(df)]=questions
    df.to_csv(path_or_buf=f"questions-{podcast_title}-{today}.csv", mode='w', index=True)
    time.sleep(2)
# Out:
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:8 - [Q1]. What did Diogenes carve into a wall in the middle of town?
# [Q2]. According to Epicurus, what is the ultimate form of pleasure and the goal of life?
# 2023-12-28 21:37:42.073 | INFO     | __main__:parse_ai_questions:96 - 10, {'EPI_NUM': 10, 'EpiName': 10, 'Podcast': 'Philosophize This', 'Person': ' What did Diogenes carve into a wall in the middle of town?', 'Abstract': ' According to Epicurus, what is the ultimate form of pleasure and the goal of life?'}
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:12 - EPI_NUM: 10
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:12 - EpiName: 10
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:12 - Person:  What did Diogenes carve into a wall in the middle of town?
# 2023-12-28 21:37:42.073 | INFO     | __main__:<module>:12 - Abstract:  According to Epicurus, what is the ultimate form of pleasure and the goal of life?
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:8 - [Q1]. What was the fine that the Romans imposed on Athens for invading and stealing from Oropus?
# [Q2]. According to the stoics, what is the central idea that all stoic ethics are centered around?
# 2023-12-28 21:37:50.045 | INFO     | __main__:parse_ai_questions:96 - 12, {'EPI_NUM': 12, 'EpiName': 12, 'Podcast': 'Philosophize This', 'Person': ' What was the fine that the Romans imposed on Athens for invading and stealing from Oropus?', 'Abstract': ' According to the stoics, what is the central idea that all stoic ethics are centered around?'}
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:12 - EPI_NUM: 12
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:12 - EpiName: 12
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:12 - Person:  What was the fine that the Romans imposed on Athens for invading and stealing from Oropus?
# 2023-12-28 21:37:50.045 | INFO     | __main__:<module>:12 - Abstract:  According to the stoics, what is the central idea that all stoic ethics are centered around?
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:8 - [Q1]. According to Plotinus, what is the reason behind the existence of evil or bad things in the world?
#
# [Q2]. How does Plotinus explain the concept of unity and its role in determining the reality of something?
# 2023-12-28 21:37:58.063 | INFO     | __main__:parse_ai_questions:96 - 15, {'EPI_NUM': 15, 'EpiName': 15, 'Podcast': 'Philosophize This', 'Person': ' According to Plotinus, what is the reason behind the existence of evil or bad things in the world?', 'Abstract': ' How does Plotinus explain the concept of unity and its role in determining the reality of something?'}
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:12 - EPI_NUM: 15
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:12 - EpiName: 15
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:12 - Person:  According to Plotinus, what is the reason behind the existence of evil or bad things in the world?
# 2023-12-28 21:37:58.063 | INFO     | __main__:<module>:12 - Abstract:  How does Plotinus explain the concept of unity and its role in determining the reality of something?
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:8 - [Q1]. How did Saint Augustine merge Neo-Platonism with Christianity?
# [Q2]. According to Saint Augustine, what is the relationship between free will and the existence of evil?
# 2023-12-28 21:38:05.400 | INFO     | __main__:parse_ai_questions:96 - 16, {'EPI_NUM': 16, 'EpiName': 16, 'Podcast': 'Philosophize This', 'Person': ' How did Saint Augustine merge Neo-Platonism with Christianity?', 'Abstract': ' According to Saint Augustine, what is the relationship between free will and the existence of evil?'}
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:12 - EPI_NUM: 16
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:12 - EpiName: 16
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:12 - Person:  How did Saint Augustine merge Neo-Platonism with Christianity?
# 2023-12-28 21:38:05.400 | INFO     | __main__:<module>:12 - Abstract:  According to Saint Augustine, what is the relationship between free will and the existence of evil?
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:8 - [Q1]. What did al-Kindi believe is the most important thing when it comes to truth?
# [Q2]. Are there things that we cannot prove with reason alone, but accept them on faith in our everyday lives?
# 2023-12-28 21:38:14.396 | INFO     | __main__:parse_ai_questions:96 - 19, {'EPI_NUM': 19, 'EpiName': 19, 'Podcast': 'Philosophize This', 'Person': ' What did al-Kindi believe is the most important thing when it comes to truth?', 'Abstract': ' Are there things that we cannot prove with reason alone, but accept them on faith in our everyday lives?'}
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:12 - EPI_NUM: 19
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:12 - EpiName: 19
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:12 - Person:  What did al-Kindi believe is the most important thing when it comes to truth?
# 2023-12-28 21:38:14.396 | INFO     | __main__:<module>:12 - Abstract:  Are there things that we cannot prove with reason alone, but accept them on faith in our everyday lives?
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:8 - [Q1]. What does Thomas Hobbes say about the nature of fear?
# [Q2]. What is the difference between Thomas Hobbes' and Francis Bacon's approach to scientific progress?
# 2023-12-28 21:38:22.047 | INFO     | __main__:parse_ai_questions:96 - 27, {'EPI_NUM': 27, 'EpiName': 27, 'Podcast': 'Philosophize This', 'Person': ' What does Thomas Hobbes say about the nature of fear?', 'Abstract': " What is the difference between Thomas Hobbes' and Francis Bacon's approach to scientific progress?"}
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:12 - EPI_NUM: 27
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:12 - EpiName: 27
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:12 - Person:  What does Thomas Hobbes say about the nature of fear?
# 2023-12-28 21:38:22.047 | INFO     | __main__:<module>:12 - Abstract:  What is the difference between Thomas Hobbes' and Francis Bacon's approach to scientific progress?
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:8 - [Q1]. What is Blaise Pascal most commonly known for?
# [Q2]. What is Pascal's wager and how does it argue for belief in God?
# 2023-12-28 21:38:32.463 | INFO     | __main__:parse_ai_questions:96 - 31, {'EPI_NUM': 31, 'EpiName': 31, 'Podcast': 'Philosophize This', 'Person': ' What is Blaise Pascal most commonly known for?', 'Abstract': " What is Pascal's wager and how does it argue for belief in God?"}
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:12 - EPI_NUM: 31
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:12 - EpiName: 31
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:12 - Person:  What is Blaise Pascal most commonly known for?
# 2023-12-28 21:38:32.463 | INFO     | __main__:<module>:12 - Abstract:  What is Pascal's wager and how does it argue for belief in God?
# 2023-12-28 21:38:40.867 | INFO     | __main__:<module>:8 - 1. Why did Blaise Pascal refer to man as the great paradox of creation?
# 2. How does Pascal view the power and detriment of the human imagination?
# 2023-12-28 21:38:40.867 | INFO     | __main__:parse_ai_questions:96 - 32, {'EPI_NUM': 32, 'EpiName': 32, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:38:40.867 | INFO     | __main__:<module>:12 - EPI_NUM: 32
# 2023-12-28 21:38:40.867 | INFO     | __main__:<module>:12 - EpiName: 32
# 2023-12-28 21:38:40.867 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:49.246 | INFO     | __main__:<module>:8 - 1. Why do people get uncomfortable when asked to explain why they believe certain things?
# 2. How did Voltaire and Locke approach the search for knowledge differently than Descartes?
# 2023-12-28 21:38:49.246 | INFO     | __main__:parse_ai_questions:96 - 41, {'EPI_NUM': 41, 'EpiName': 41, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:38:49.246 | INFO     | __main__:<module>:12 - EPI_NUM: 41
# 2023-12-28 21:38:49.248 | INFO     | __main__:<module>:12 - EpiName: 41
# 2023-12-28 21:38:49.248 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:56.648 | INFO     | __main__:<module>:8 - [Q1]. What is the function of the government according to Rousseau?
# [Q2]. How does Rousseau define the general will and why is it difficult to determine?
# 2023-12-28 21:38:56.648 | INFO     | __main__:parse_ai_questions:96 - 47, {'EPI_NUM': 47, 'EpiName': 47, 'Podcast': 'Philosophize This', 'Person': ' What is the function of the government according to Rousseau?', 'Abstract': ' How does Rousseau define the general will and why is it difficult to determine?'}
# 2023-12-28 21:38:56.663 | INFO     | __main__:<module>:12 - EPI_NUM: 47
# 2023-12-28 21:38:56.663 | INFO     | __main__:<module>:12 - EpiName: 47
# 2023-12-28 21:38:56.663 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:38:56.663 | INFO     | __main__:<module>:12 - Person:  What is the function of the government according to Rousseau?
# 2023-12-28 21:38:56.663 | INFO     | __main__:<module>:12 - Abstract:  How does Rousseau define the general will and why is it difficult to determine?
# 2023-12-28 21:39:04.847 | INFO     | __main__:<module>:8 - [Q1]. What does Adam Smith talk about at length in his work?
# [Q2]. How does specialization and self-interested bargains benefit society as a whole?
# 2023-12-28 21:39:04.847 | INFO     | __main__:parse_ai_questions:96 - 48, {'EPI_NUM': 48, 'EpiName': 48, 'Podcast': 'Philosophize This', 'Person': ' What does Adam Smith talk about at length in his work?', 'Abstract': ' How does specialization and self-interested bargains benefit society as a whole?'}
# 2023-12-28 21:39:04.847 | INFO     | __main__:<module>:12 - EPI_NUM: 48
# 2023-12-28 21:39:04.849 | INFO     | __main__:<module>:12 - EpiName: 48
# 2023-12-28 21:39:04.849 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:04.849 | INFO     | __main__:<module>:12 - Person:  What does Adam Smith talk about at length in his work?
# 2023-12-28 21:39:04.849 | INFO     | __main__:<module>:12 - Abstract:  How does specialization and self-interested bargains benefit society as a whole?
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:8 - [Q1]. What is the difference between deontology and consequentialism in terms of determining the morality of an action?
# [Q2]. How does the concept of duty play a role in deontology and the concept of consequences play a role in consequentialism in ethical decision-making?
# 2023-12-28 21:39:16.082 | INFO     | __main__:parse_ai_questions:96 - 58, {'EPI_NUM': 58, 'EpiName': 58, 'Podcast': 'Philosophize This', 'Person': ' What is the difference between deontology and consequentialism in terms of determining the morality of an action?', 'Abstract': ' How does the concept of duty play a role in deontology and the concept of consequences play a role in consequentialism in ethical decision-making?'}
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:12 - EPI_NUM: 58
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:12 - EpiName: 58
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:12 - Person:  What is the difference between deontology and consequentialism in terms of determining the morality of an action?
# 2023-12-28 21:39:16.082 | INFO     | __main__:<module>:12 - Abstract:  How does the concept of duty play a role in deontology and the concept of consequences play a role in consequentialism in ethical decision-making?
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:8 - [Q1]. What was the title of Johann Biester's essay published in the magazine?
#
# [Q2]. What does Immanuel Kant define as "enlightenment"?
# 2023-12-28 21:39:24.048 | INFO     | __main__:parse_ai_questions:96 - 61, {'EPI_NUM': 61, 'EpiName': 61, 'Podcast': 'Philosophize This', 'Person': " What was the title of Johann Biester's essay published in the magazine?", 'Abstract': ' What does Immanuel Kant define as "enlightenment"?'}
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:12 - EPI_NUM: 61
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:12 - EpiName: 61
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:12 - Person:  What was the title of Johann Biester's essay published in the magazine?
# 2023-12-28 21:39:24.048 | INFO     | __main__:<module>:12 - Abstract:  What does Immanuel Kant define as "enlightenment"?
# 2023-12-28 21:39:33.132 | INFO     | __main__:<module>:8 - 1. Why do people seek knowledge about the world instead of not seeking knowledge?
# 2. Are there things in the world that we just can't know or perceive?
# 2023-12-28 21:39:33.132 | INFO     | __main__:parse_ai_questions:96 - 63, {'EPI_NUM': 63, 'EpiName': 63, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:39:33.132 | INFO     | __main__:<module>:12 - EPI_NUM: 63
# 2023-12-28 21:39:33.132 | INFO     | __main__:<module>:12 - EpiName: 63
# 2023-12-28 21:39:33.132 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:40.849 | INFO     | __main__:<module>:8 - 1. What is the main subject discussed in this document?
# 2. How does Friedrich Schleiermacher define hermeneutics?
# 2023-12-28 21:39:40.849 | INFO     | __main__:parse_ai_questions:96 - 64, {'EPI_NUM': 64, 'EpiName': 64, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:39:40.849 | INFO     | __main__:<module>:12 - EPI_NUM: 64
# 2023-12-28 21:39:40.849 | INFO     | __main__:<module>:12 - EpiName: 64
# 2023-12-28 21:39:40.849 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:48.186 | INFO     | __main__:<module>:8 - [Q1]. What is the argument from consequences fallacy?
#
# [Q2]. What is the false equivalence fallacy?
# 2023-12-28 21:39:48.199 | INFO     | __main__:parse_ai_questions:96 - 73, {'EPI_NUM': 73, 'EpiName': 73, 'Podcast': 'Philosophize This', 'Person': ' What is the argument from consequences fallacy?', 'Abstract': ' What is the false equivalence fallacy?'}
# 2023-12-28 21:39:48.199 | INFO     | __main__:<module>:12 - EPI_NUM: 73
# 2023-12-28 21:39:48.199 | INFO     | __main__:<module>:12 - EpiName: 73
# 2023-12-28 21:39:48.199 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:48.199 | INFO     | __main__:<module>:12 - Person:  What is the argument from consequences fallacy?
# 2023-12-28 21:39:48.199 | INFO     | __main__:<module>:12 - Abstract:  What is the false equivalence fallacy?
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:8 - [Q1]. What are the limitations of winning an argument or pointing out your opponent's logical fallacies in politics?
# [Q2]. Why is it important to be able to spot logical fallacies in arguments?
# 2023-12-28 21:39:56.432 | INFO     | __main__:parse_ai_questions:96 - 75, {'EPI_NUM': 75, 'EpiName': 75, 'Podcast': 'Philosophize This', 'Person': " What are the limitations of winning an argument or pointing out your opponent's logical fallacies in politics?", 'Abstract': ' Why is it important to be able to spot logical fallacies in arguments?'}
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:12 - EPI_NUM: 75
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:12 - EpiName: 75
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:12 - Person:  What are the limitations of winning an argument or pointing out your opponent's logical fallacies in politics?
# 2023-12-28 21:39:56.432 | INFO     | __main__:<module>:12 - Abstract:  Why is it important to be able to spot logical fallacies in arguments?
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:8 - [Q1]. According to the document, what does Hegel believe God is?
# [Q2]. Why does the author argue that it is important to entertain the possibility of a God existing?
# 2023-12-28 21:40:03.733 | INFO     | __main__:parse_ai_questions:96 - 76, {'EPI_NUM': 76, 'EpiName': 76, 'Podcast': 'Philosophize This', 'Person': ' According to the document, what does Hegel believe God is?', 'Abstract': ' Why does the author argue that it is important to entertain the possibility of a God existing?'}
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:12 - EPI_NUM: 76
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:12 - EpiName: 76
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:12 - Person:  According to the document, what does Hegel believe God is?
# 2023-12-28 21:40:03.733 | INFO     | __main__:<module>:12 - Abstract:  Why does the author argue that it is important to entertain the possibility of a God existing?
# 2023-12-28 21:40:09.631 | INFO     | __main__:<module>:8 - 1. What is the concept of bad faith that Sartre discusses?
# 2. How does Sartre argue that existence precedes essence?
# 2023-12-28 21:40:09.631 | INFO     | __main__:parse_ai_questions:96 - 86, {'EPI_NUM': 86, 'EpiName': 86, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:40:09.632 | INFO     | __main__:<module>:12 - EPI_NUM: 86
# 2023-12-28 21:40:09.632 | INFO     | __main__:<module>:12 - EpiName: 86
# 2023-12-28 21:40:09.632 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:17.720 | INFO     | __main__:<module>:8 - [Q1]. Is it justifiable to kill innocent people as a political means to an end?
# [Q2]. What is the difference in thinking between Sartre and Camus regarding revolutions?
# 2023-12-28 21:40:17.720 | INFO     | __main__:parse_ai_questions:96 - 88, {'EPI_NUM': 88, 'EpiName': 88, 'Podcast': 'Philosophize This', 'Person': ' Is it justifiable to kill innocent people as a political means to an end?', 'Abstract': ' What is the difference in thinking between Sartre and Camus regarding revolutions?'}
# 2023-12-28 21:40:17.721 | INFO     | __main__:<module>:12 - EPI_NUM: 88
# 2023-12-28 21:40:17.721 | INFO     | __main__:<module>:12 - EpiName: 88
# 2023-12-28 21:40:17.722 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:17.722 | INFO     | __main__:<module>:12 - Person:  Is it justifiable to kill innocent people as a political means to an end?
# 2023-12-28 21:40:17.722 | INFO     | __main__:<module>:12 - Abstract:  What is the difference in thinking between Sartre and Camus regarding revolutions?
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:8 - [Q1]. What does Nietzsche believe is the reason why most people are not nihilistic?
# [Q2]. Why does Nietzsche argue that envy is a powerful tool for personal growth?
# 2023-12-28 21:40:25.920 | INFO     | __main__:parse_ai_questions:96 - 90, {'EPI_NUM': 90, 'EpiName': 90, 'Podcast': 'Philosophize This', 'Person': ' What does Nietzsche believe is the reason why most people are not nihilistic?', 'Abstract': ' Why does Nietzsche argue that envy is a powerful tool for personal growth?'}
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:12 - EPI_NUM: 90
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:12 - EpiName: 90
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:12 - Person:  What does Nietzsche believe is the reason why most people are not nihilistic?
# 2023-12-28 21:40:25.920 | INFO     | __main__:<module>:12 - Abstract:  Why does Nietzsche argue that envy is a powerful tool for personal growth?
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:8 - [Q1]. What is the main character of Nietzsche's book Thus Spoke Zarathustra known for?
# [Q2]. According to Nietzsche, what is the ultimate goal of human development?
# 2023-12-28 21:40:34.136 | INFO     | __main__:parse_ai_questions:96 - 92, {'EPI_NUM': 92, 'EpiName': 92, 'Podcast': 'Philosophize This', 'Person': " What is the main character of Nietzsche's book Thus Spoke Zarathustra known for?", 'Abstract': ' According to Nietzsche, what is the ultimate goal of human development?'}
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:12 - EPI_NUM: 92
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:12 - EpiName: 92
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:12 - Person:  What is the main character of Nietzsche's book Thus Spoke Zarathustra known for?
# 2023-12-28 21:40:34.136 | INFO     | __main__:<module>:12 - Abstract:  According to Nietzsche, what is the ultimate goal of human development?
# 2023-12-28 21:40:40.033 | INFO     | __main__:<module>:8 - [Q1]. According to Nietzsche, how does love resemble greed?
# [Q2]. What does Nietzsche think about love and friendship?
# 2023-12-28 21:40:40.049 | INFO     | __main__:parse_ai_questions:96 - 93, {'EPI_NUM': 93, 'EpiName': 93, 'Podcast': 'Philosophize This', 'Person': ' According to Nietzsche, how does love resemble greed?', 'Abstract': ' What does Nietzsche think about love and friendship?'}
# 2023-12-28 21:40:40.049 | INFO     | __main__:<module>:12 - EPI_NUM: 93
# 2023-12-28 21:40:40.049 | INFO     | __main__:<module>:12 - EpiName: 93
# 2023-12-28 21:40:40.049 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:40.049 | INFO     | __main__:<module>:12 - Person:  According to Nietzsche, how does love resemble greed?
# 2023-12-28 21:40:40.049 | INFO     | __main__:<module>:12 - Abstract:  What does Nietzsche think about love and friendship?
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:8 - [Q1]. What is the concept of Dasein according to Heidegger?
#
# [Q2]. Why does Heidegger believe that understanding ontological questions is important for addressing real-world problems?
# 2023-12-28 21:40:47.784 | INFO     | __main__:parse_ai_questions:96 - 100, {'EPI_NUM': 100, 'EpiName': 100, 'Podcast': 'Philosophize This', 'Person': ' What is the concept of Dasein according to Heidegger?', 'Abstract': ' Why does Heidegger believe that understanding ontological questions is important for addressing real-world problems?'}
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:12 - EPI_NUM: 100
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:12 - EpiName: 100
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:12 - Person:  What is the concept of Dasein according to Heidegger?
# 2023-12-28 21:40:47.784 | INFO     | __main__:<module>:12 - Abstract:  Why does Heidegger believe that understanding ontological questions is important for addressing real-world problems?
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:8 - [Q1]. What is Sartre's view on consciousness and the world?
# [Q2]. How does Sartre challenge the idea of understanding things through universal essences?
# 2023-12-28 21:40:57.269 | INFO     | __main__:parse_ai_questions:96 - 103, {'EPI_NUM': 103, 'EpiName': 103, 'Podcast': 'Philosophize This', 'Person': " What is Sartre's view on consciousness and the world?", 'Abstract': ' How does Sartre challenge the idea of understanding things through universal essences?'}
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:12 - EPI_NUM: 103
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:12 - EpiName: 103
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:12 - Person:  What is Sartre's view on consciousness and the world?
# 2023-12-28 21:40:57.269 | INFO     | __main__:<module>:12 - Abstract:  How does Sartre challenge the idea of understanding things through universal essences?
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:8 - [Q1]. What does Sartre mean when he says that consciousness is freedom?
#
# [Q2]. How does Sartre explain the relationship between consciousness and emotions?
# 2023-12-28 21:41:05.835 | INFO     | __main__:parse_ai_questions:96 - 104, {'EPI_NUM': 104, 'EpiName': 104, 'Podcast': 'Philosophize This', 'Person': ' What does Sartre mean when he says that consciousness is freedom?', 'Abstract': ' How does Sartre explain the relationship between consciousness and emotions?'}
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:12 - EPI_NUM: 104
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:12 - EpiName: 104
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:12 - Person:  What does Sartre mean when he says that consciousness is freedom?
# 2023-12-28 21:41:05.835 | INFO     | __main__:<module>:12 - Abstract:  How does Sartre explain the relationship between consciousness and emotions?
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:8 - [Q1]. What are the different personality types that Simone de Beauvoir describes in her book "The Ethics of Ambiguity"?
#
# [Q2]. What is the significance of embracing the ambiguity of existence according to Simone de Beauvoir?
# 2023-12-28 21:41:14.785 | INFO     | __main__:parse_ai_questions:96 - 106, {'EPI_NUM': 106, 'EpiName': 106, 'Podcast': 'Philosophize This', 'Person': ' What are the different personality types that Simone de Beauvoir describes in her book "The Ethics of Ambiguity"?', 'Abstract': ' What is the significance of embracing the ambiguity of existence according to Simone de Beauvoir?'}
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:12 - EPI_NUM: 106
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:12 - EpiName: 106
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:12 - Person:  What are the different personality types that Simone de Beauvoir describes in her book "The Ethics of Ambiguity"?
# 2023-12-28 21:41:14.785 | INFO     | __main__:<module>:12 - Abstract:  What is the significance of embracing the ambiguity of existence according to Simone de Beauvoir?
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:8 - [Q1]. How does Camus suggest that Sisyphus find happiness in his repetitive task?
# [Q2]. What are the goals of the Frankfurt School in their critique of Enlightenment-style thinking?
# 2023-12-28 21:41:22.702 | INFO     | __main__:parse_ai_questions:96 - 108, {'EPI_NUM': 108, 'EpiName': 108, 'Podcast': 'Philosophize This', 'Person': ' How does Camus suggest that Sisyphus find happiness in his repetitive task?', 'Abstract': ' What are the goals of the Frankfurt School in their critique of Enlightenment-style thinking?'}
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:12 - EPI_NUM: 108
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:12 - EpiName: 108
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:12 - Person:  How does Camus suggest that Sisyphus find happiness in his repetitive task?
# 2023-12-28 21:41:22.702 | INFO     | __main__:<module>:12 - Abstract:  What are the goals of the Frankfurt School in their critique of Enlightenment-style thinking?
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:8 - [Q1]. What is the Great Refusal and how did Herbert Marcuse view it?
#
# [Q2]. How does Marcuse argue that social conditioning affects our behavior and perception of the world?
# 2023-12-28 21:41:33.423 | INFO     | __main__:parse_ai_questions:96 - 114, {'EPI_NUM': 114, 'EpiName': 114, 'Podcast': 'Philosophize This', 'Person': ' What is the Great Refusal and how did Herbert Marcuse view it?', 'Abstract': ' How does Marcuse argue that social conditioning affects our behavior and perception of the world?'}
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:12 - EPI_NUM: 114
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:12 - EpiName: 114
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:12 - Person:  What is the Great Refusal and how did Herbert Marcuse view it?
# 2023-12-28 21:41:33.423 | INFO     | __main__:<module>:12 - Abstract:  How does Marcuse argue that social conditioning affects our behavior and perception of the world?
# 2023-12-28 21:41:40.607 | INFO     | __main__:<module>:8 - 1. What is the concept of a synthetic a priori proposition and why is it important in philosophy?
# 2. How did structuralism challenge the traditional understanding of subjectivity and history?
# 2023-12-28 21:41:40.607 | INFO     | __main__:parse_ai_questions:96 - 115, {'EPI_NUM': 115, 'EpiName': 115, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:41:40.607 | INFO     | __main__:<module>:12 - EPI_NUM: 115
# 2023-12-28 21:41:40.607 | INFO     | __main__:<module>:12 - EpiName: 115
# 2023-12-28 21:41:40.607 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:47.169 | INFO     | __main__:<module>:8 - [Q1]. What is the main premise of the logical positivists' philosophy?
# [Q2]. How did Thomas Kuhn challenge the idea of scientific progress?
# 2023-12-28 21:41:47.170 | INFO     | __main__:parse_ai_questions:96 - 120, {'EPI_NUM': 120, 'EpiName': 120, 'Podcast': 'Philosophize This', 'Person': " What is the main premise of the logical positivists' philosophy?", 'Abstract': ' How did Thomas Kuhn challenge the idea of scientific progress?'}
# 2023-12-28 21:41:47.171 | INFO     | __main__:<module>:12 - EPI_NUM: 120
# 2023-12-28 21:41:47.171 | INFO     | __main__:<module>:12 - EpiName: 120
# 2023-12-28 21:41:47.172 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:47.172 | INFO     | __main__:<module>:12 - Person:  What is the main premise of the logical positivists' philosophy?
# 2023-12-28 21:41:47.173 | INFO     | __main__:<module>:12 - Abstract:  How did Thomas Kuhn challenge the idea of scientific progress?
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:8 - [Q1]. What was the punishment carried out on a criminal in the year 1757?
# [Q2]. What does Foucault argue is the goal of the modern penal system?
# 2023-12-28 21:41:56.552 | INFO     | __main__:parse_ai_questions:96 - 121, {'EPI_NUM': 121, 'EpiName': 121, 'Podcast': 'Philosophize This', 'Person': ' What was the punishment carried out on a criminal in the year 1757?', 'Abstract': ' What does Foucault argue is the goal of the modern penal system?'}
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:12 - EPI_NUM: 121
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:12 - EpiName: 121
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:12 - Person:  What was the punishment carried out on a criminal in the year 1757?
# 2023-12-28 21:41:56.552 | INFO     | __main__:<module>:12 - Abstract:  What does Foucault argue is the goal of the modern penal system?
# 2023-12-28 21:42:03.541 | INFO     | __main__:<module>:8 - [Q1]. What is the main argument of the repressive hypothesis in Michel Foucault's work?
#
# [Q2]. How does Foucault describe the exercise of power in our modern societies?
# 2023-12-28 21:42:03.542 | INFO     | __main__:parse_ai_questions:96 - 123, {'EPI_NUM': 123, 'EpiName': 123, 'Podcast': 'Philosophize This', 'Person': " What is the main argument of the repressive hypothesis in Michel Foucault's work?", 'Abstract': ' How does Foucault describe the exercise of power in our modern societies?'}
# 2023-12-28 21:42:03.543 | INFO     | __main__:<module>:12 - EPI_NUM: 123
# 2023-12-28 21:42:03.543 | INFO     | __main__:<module>:12 - EpiName: 123
# 2023-12-28 21:42:03.543 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:03.544 | INFO     | __main__:<module>:12 - Person:  What is the main argument of the repressive hypothesis in Michel Foucault's work?
# 2023-12-28 21:42:03.544 | INFO     | __main__:<module>:12 - Abstract:  How does Foucault describe the exercise of power in our modern societies?
# 2023-12-28 21:42:11.753 | INFO     | __main__:<module>:8 - [Q1]. How does Deleuze suggest we should look at politics?
#
# [Q2]. How does Deleuze define a machine in the context of politics?
# 2023-12-28 21:42:11.753 | INFO     | __main__:parse_ai_questions:96 - 127, {'EPI_NUM': 127, 'EpiName': 127, 'Podcast': 'Philosophize This', 'Person': ' How does Deleuze suggest we should look at politics?', 'Abstract': ' How does Deleuze define a machine in the context of politics?'}
# 2023-12-28 21:42:11.768 | INFO     | __main__:<module>:12 - EPI_NUM: 127
# 2023-12-28 21:42:11.768 | INFO     | __main__:<module>:12 - EpiName: 127
# 2023-12-28 21:42:11.769 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:11.769 | INFO     | __main__:<module>:12 - Person:  How does Deleuze suggest we should look at politics?
# 2023-12-28 21:42:11.769 | INFO     | __main__:<module>:12 - Abstract:  How does Deleuze define a machine in the context of politics?
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:8 - [Q1]. How does Deleuze suggest we should think about social theory differently?
# [Q2]. What does Deleuze argue is the relationship between identity and difference?
# 2023-12-28 21:42:18.586 | INFO     | __main__:parse_ai_questions:96 - 128, {'EPI_NUM': 128, 'EpiName': 128, 'Podcast': 'Philosophize This', 'Person': ' How does Deleuze suggest we should think about social theory differently?', 'Abstract': ' What does Deleuze argue is the relationship between identity and difference?'}
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:12 - EPI_NUM: 128
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:12 - EpiName: 128
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:12 - Person:  How does Deleuze suggest we should think about social theory differently?
# 2023-12-28 21:42:18.586 | INFO     | __main__:<module>:12 - Abstract:  What does Deleuze argue is the relationship between identity and difference?
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:8 - [Q1]. What is the mistake people often make when trying to understand their own personal identity, according to Deleuze?
# [Q2]. How does Deleuze view the world and what is his call to action?
# 2023-12-28 21:42:26.490 | INFO     | __main__:parse_ai_questions:96 - 129, {'EPI_NUM': 129, 'EpiName': 129, 'Podcast': 'Philosophize This', 'Person': ' What is the mistake people often make when trying to understand their own personal identity, according to Deleuze?', 'Abstract': ' How does Deleuze view the world and what is his call to action?'}
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:12 - EPI_NUM: 129
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:12 - EpiName: 129
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:12 - Person:  What is the mistake people often make when trying to understand their own personal identity, according to Deleuze?
# 2023-12-28 21:42:26.490 | INFO     | __main__:<module>:12 - Abstract:  How does Deleuze view the world and what is his call to action?
# 2023-12-28 21:42:32.859 | INFO     | __main__:<module>:8 - [Q1]. What is Antonio Gramsci's main focus in his work?
# [Q2]. How does cultural hegemony contribute to maintaining the status quo?
# 2023-12-28 21:42:32.860 | INFO     | __main__:parse_ai_questions:96 - 131, {'EPI_NUM': 131, 'EpiName': 131, 'Podcast': 'Philosophize This', 'Person': " What is Antonio Gramsci's main focus in his work?", 'Abstract': ' How does cultural hegemony contribute to maintaining the status quo?'}
# 2023-12-28 21:42:32.860 | INFO     | __main__:<module>:12 - EPI_NUM: 131
# 2023-12-28 21:42:32.860 | INFO     | __main__:<module>:12 - EpiName: 131
# 2023-12-28 21:42:32.860 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:32.860 | INFO     | __main__:<module>:12 - Person:  What is Antonio Gramsci's main focus in his work?
# 2023-12-28 21:42:32.860 | INFO     | __main__:<module>:12 - Abstract:  How does cultural hegemony contribute to maintaining the status quo?
# 2023-12-28 21:42:39.840 | INFO     | __main__:<module>:8 - [Q1]. What does Carl Schmitt criticize about liberalism?
# [Q2]. How does Carl Schmitt view the concept of a sovereign in liberal societies?
# 2023-12-28 21:42:39.854 | INFO     | __main__:parse_ai_questions:96 - 132, {'EPI_NUM': 132, 'EpiName': 132, 'Podcast': 'Philosophize This', 'Person': ' What does Carl Schmitt criticize about liberalism?', 'Abstract': ' How does Carl Schmitt view the concept of a sovereign in liberal societies?'}
# 2023-12-28 21:42:39.854 | INFO     | __main__:<module>:12 - EPI_NUM: 132
# 2023-12-28 21:42:39.854 | INFO     | __main__:<module>:12 - EpiName: 132
# 2023-12-28 21:42:39.854 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:39.854 | INFO     | __main__:<module>:12 - Person:  What does Carl Schmitt criticize about liberalism?
# 2023-12-28 21:42:39.854 | INFO     | __main__:<module>:12 - Abstract:  How does Carl Schmitt view the concept of a sovereign in liberal societies?
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:8 - [Q1]. What is Richard Rorty's view on the philosophical grounding of human rights?
# [Q2]. How does Richard Rorty define an "ironist" and what is their approach to worldview and argumentation?
# 2023-12-28 21:42:47.471 | INFO     | __main__:parse_ai_questions:96 - 142, {'EPI_NUM': 142, 'EpiName': 142, 'Podcast': 'Philosophize This', 'Person': " What is Richard Rorty's view on the philosophical grounding of human rights?", 'Abstract': ' How does Richard Rorty define an "ironist" and what is their approach to worldview and argumentation?'}
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:12 - EPI_NUM: 142
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:12 - EpiName: 142
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:12 - Person:  What is Richard Rorty's view on the philosophical grounding of human rights?
# 2023-12-28 21:42:47.471 | INFO     | __main__:<module>:12 - Abstract:  How does Richard Rorty define an "ironist" and what is their approach to worldview and argumentation?
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:8 - [Q1]. According to Henri Bergson, why do we find certain things funny?
#
# [Q2]. How does Bergson's theory of laughter incorporate elements from the superiority, relief, and incongruity theories?
# 2023-12-28 21:42:54.874 | INFO     | __main__:parse_ai_questions:96 - 145, {'EPI_NUM': 145, 'EpiName': 145, 'Podcast': 'Philosophize This', 'Person': ' According to Henri Bergson, why do we find certain things funny?', 'Abstract': " How does Bergson's theory of laughter incorporate elements from the superiority, relief, and incongruity theories?"}
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:12 - EPI_NUM: 145
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:12 - EpiName: 145
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:12 - Person:  According to Henri Bergson, why do we find certain things funny?
# 2023-12-28 21:42:54.874 | INFO     | __main__:<module>:12 - Abstract:  How does Bergson's theory of laughter incorporate elements from the superiority, relief, and incongruity theories?
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:8 - [Q1]. What is the task of the translator according to Walter Benjamin?
# [Q2]. How does the introduction of new technology, like photography, change the experience of people according to Benjamin?
# 2023-12-28 21:43:02.042 | INFO     | __main__:parse_ai_questions:96 - 152, {'EPI_NUM': 152, 'EpiName': 152, 'Podcast': 'Philosophize This', 'Person': ' What is the task of the translator according to Walter Benjamin?', 'Abstract': ' How does the introduction of new technology, like photography, change the experience of people according to Benjamin?'}
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:12 - EPI_NUM: 152
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:12 - EpiName: 152
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:12 - Person:  What is the task of the translator according to Walter Benjamin?
# 2023-12-28 21:43:02.042 | INFO     | __main__:<module>:12 - Abstract:  How does the introduction of new technology, like photography, change the experience of people according to Benjamin?
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:8 - [Q1]. What is the value that Kierkegaard emphasizes in the first discourse of his work "The Lily of the Field and Bird of the Air"?
#
# [Q2]. How does Kierkegaard view obedience in relation to sticking to a system of values?
# 2023-12-28 21:43:11.855 | INFO     | __main__:parse_ai_questions:96 - 160, {'EPI_NUM': 160, 'EpiName': 160, 'Podcast': 'Philosophize This', 'Person': ' What is the value that Kierkegaard emphasizes in the first discourse of his work "The Lily of the Field and Bird of the Air"?', 'Abstract': ' How does Kierkegaard view obedience in relation to sticking to a system of values?'}
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:12 - EPI_NUM: 160
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:12 - EpiName: 160
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:12 - Person:  What is the value that Kierkegaard emphasizes in the first discourse of his work "The Lily of the Field and Bird of the Air"?
# 2023-12-28 21:43:11.855 | INFO     | __main__:<module>:12 - Abstract:  How does Kierkegaard view obedience in relation to sticking to a system of values?
# 2023-12-28 21:43:19.122 | INFO     | __main__:<module>:8 - 1. What is the main concept that Bruno Latour discusses in his book "We Have Never Been Modern"?
# 2. How does Bruno Latour suggest we should view the world in order to gain a better understanding of it?
# 2023-12-28 21:43:19.122 | INFO     | __main__:parse_ai_questions:96 - 169, {'EPI_NUM': 169, 'EpiName': 169, 'Podcast': 'Philosophize This'}
# 2023-12-28 21:43:19.122 | INFO     | __main__:<module>:12 - EPI_NUM: 169
# 2023-12-28 21:43:19.122 | INFO     | __main__:<module>:12 - EpiName: 169
# 2023-12-28 21:43:19.122 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:8 - [Q1]. What strategies does Clamence use to avoid being judged by others?
#
# [Q2]. How does Clamence's strategy as a judge-penitent help him avoid guilt and criticism?
# 2023-12-28 21:43:25.826 | INFO     | __main__:parse_ai_questions:96 - 170, {'EPI_NUM': 170, 'EpiName': 170, 'Podcast': 'Philosophize This', 'Person': ' What strategies does Clamence use to avoid being judged by others?', 'Abstract': " How does Clamence's strategy as a judge-penitent help him avoid guilt and criticism?"}
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:12 - EPI_NUM: 170
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:12 - EpiName: 170
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:12 - Person:  What strategies does Clamence use to avoid being judged by others?
# 2023-12-28 21:43:25.826 | INFO     | __main__:<module>:12 - Abstract:  How does Clamence's strategy as a judge-penitent help him avoid guilt and criticism?
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:8 - [Q1]. What is Simone Weil's perspective on the concept of roots and its importance in human life?
# [Q2]. How does Simone Weil propose a spiritual revolution through the cultivation of a different kind of attention?
# 2023-12-28 21:43:34.255 | INFO     | __main__:parse_ai_questions:96 - 173, {'EPI_NUM': 173, 'EpiName': 173, 'Podcast': 'Philosophize This', 'Person': " What is Simone Weil's perspective on the concept of roots and its importance in human life?", 'Abstract': ' How does Simone Weil propose a spiritual revolution through the cultivation of a different kind of attention?'}
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:12 - EPI_NUM: 173
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:12 - EpiName: 173
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:12 - Person:  What is Simone Weil's perspective on the concept of roots and its importance in human life?
# 2023-12-28 21:43:34.255 | INFO     | __main__:<module>:12 - Abstract:  How does Simone Weil propose a spiritual revolution through the cultivation of a different kind of attention?
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:8 - [Q1]. What is Susan Sontag's view on the role of cultural critics?
# [Q2]. How does Susan Sontag suggest experiencing works of art in a different way?
# 2023-12-28 21:43:41.973 | INFO     | __main__:parse_ai_questions:96 - 176, {'EPI_NUM': 176, 'EpiName': 176, 'Podcast': 'Philosophize This', 'Person': " What is Susan Sontag's view on the role of cultural critics?", 'Abstract': ' How does Susan Sontag suggest experiencing works of art in a different way?'}
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:12 - EPI_NUM: 176
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:12 - EpiName: 176
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:12 - Podcast: Philosophize This
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:12 - Person:  What is Susan Sontag's view on the role of cultural critics?
# 2023-12-28 21:43:41.973 | INFO     | __main__:<module>:12 - Abstract:  How does Susan Sontag suggest experiencing works of art in a different way?
